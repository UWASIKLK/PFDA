# %% [markdown]
# ### Subplots
#
# We need to import relevant packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# The parameters we need to set up are `ncols, nrows` and we can use `figsize` to setup up the size

# %%
num_cols = 2
num_rows = 2

fig, axs = plt.subplots(ncols = num_cols, nrows = num_rows, figsize = (5.5,3.5), layout = "constrained")

for row in range(num_rows):
    for col in range (num_cols):
        axs[row,col].annotate(f"plot[{row},{col}]", (0.5,0.5), ha="center", color ="grey")

plt.show()

# %% [markdown]
# ### Example
#
# created some data

# %%
data = [
    [2,4,5,6,3,5,6,7],
    [9,8,7,6,5,4,3,2],
    [1,2,3,4,5,6,7,8],
    [5,5,5,5,5,5,5,5]
]
x = 0.3 + np.arange(8)

num_cols = 2
num_rows = 2

fig, axs = plt.subplots(ncols = num_cols, nrows = num_rows, figsize = (5.5,3.5), layout = "constrained")
count = 0
for row in range(num_rows):
    for col in range (num_cols):
        axs[row,col].plot(x,data[count])
        count += 1

plt.show()
